# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaPaesano/Dados-de-Tabela-HTML-para-CSV/blob/main/Dados_de_Tabela_HTML_para_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar a biblioteca
import pandas as pd

# %%
# URL da página da Wikipédia
url = ('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')

# %%
# Ler as tabelas da página
dados = pd.read_html(url)

# %%
# Selecionar a tabela correta
df_populacao = dados[0]

# %%
# Selecionar apenas as colunas necessárias
df_reduzido = df_populacao[['País (ou território dependente)', 'Estimativa da ONU']]

# Visualizar as primeiras linhas
df_reduzido.head()
# Out:
#   País (ou território dependente) Estimativa da ONU
# 0                           Índia     1 429 921 746
# 1                           China     1 426 391 281
# 2                  Estados Unidos       346 353 341
# 3                       Indonésia       277 184 719
# 4                       Paquistão       240 215 932

# %%
# Exportar para CSV
df_reduzido.to_csv('populacao_paises.csv', index=False)
